# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df = df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 77    22            27000          0
# 327   42            75000          0
# 341   35            75000          0
# 133   21            68000          0
# 235   46            79000          1

# %% [markdown]
# # Train test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop('Purchased', axis=1),
                                                df['Purchased'], 
                                                test_size = 0.3, 
                                                random_state = 0)

X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# #  StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()

scaler.fit(X_train)
scaler.fit(X_test)
 
X_train_scaled = scaler.transform(X_train)
X_test_Scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.71666667e+01, 6.95916667e+04])

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
X_train_scaled
# Out:
# array([[-1.00978765, -1.66457226],
#        [ 2.06478966,  0.98817303],
#        [ 0.07535729,  1.29308628],
#        [ 0.25621478,  1.14062966],
#        [ 0.43707226, -0.5059019 ],
#        [-0.19592895, -0.32295395],
#        [ 0.97964473, -0.87179781],
#        [ 0.97964473,  1.96389544],
#        [ 0.07535729,  1.32357761],
#        [-0.73850141,  2.39077399],
#        [-1.00978765, -1.66457226],
#        [ 2.06478966, -0.84130648],
#        [-1.19064513, -1.54260696],
#        [ 0.43707226,  2.42126531],
#        [ 0.79878724,  0.80522508],
#        [-0.82893016, -0.32295395],
#        [ 0.16578603,  0.80522508],
#        [-0.82893016,  0.5917858 ],
#        [ 0.34664352,  0.07343327],
#        [ 0.7083585 , -1.32916768],
#        [-0.37678643, -0.0180407 ],
#        [-1.55236011,  0.37834653],
#        [-0.55764392,  0.13441593],
#        [ 0.43707226,  0.31736388],
#        [-0.19592895,  0.07343327],
#        [-0.37678643,  2.42126531],
#        [ 0.25621478,  0.04294195],
#        [ 1.25093096,  2.32979134],
#        [ 0.79878724,  0.28687255],
#        [-0.19592895,  0.16490725],
#        [ 0.07535729, -0.56688455],
#        [-0.1055002 ,  0.16490725],
#        [-0.01507146,  0.25638123],
#        [ 0.07535729, -0.2619713 ],
#        [ 2.06478966,  1.17112098],
#        [-1.55236011,  0.37834653],
#        [ 1.79350343,  0.13441593],
#        [ 0.43707226, -0.140006  ],
#        [-1.00978765,  0.31736388],
#        [ 0.79878724,  1.44554291],
#        [-0.19592895, -0.2619713 ],
#        [-1.46193137, -0.04853203],
#        [-0.82893016, -0.78032383],
#        [ 0.34664352,  0.53080315],
#        [-0.01507146, -1.11572841],
#        [-0.9193589 ,  0.62227713],
#        [ 0.16578603, -0.84130648],
#        [-0.82893016,  1.62849086],
#        [-0.55764392,  1.47603423],
#        [-1.10021639,  0.53080315],
#        [-0.19592895,  0.04294195],
#        [-0.01507146,  0.01245062],
#        [-0.19592895, -0.93278046],
#        [ 0.88921599, -1.42064166],
#        [-0.19592895,  2.36028266],
#        [ 0.97964473,  2.08586074],
#        [-1.00978765,  0.50031183],
#        [-1.10021639,  0.28687255],
#        [ 1.34135971,  2.08586074],
#        [ 1.25093096, -1.42064166],
#        [-0.19592895, -0.29246263],
#        [-0.37678643,  1.32357761],
#        [-0.64807267,  1.14062966],
#        [ 0.97964473, -1.11572841],
#        [ 0.34664352,  0.31736388],
#        [ 0.97964473,  0.80522508],
#        [-0.55764392, -1.57309829],
#        [-0.55764392,  0.04294195],
#        [ 0.52750101,  1.81143881],
#        [ 1.97436092,  0.19539858],
#        [-1.7332176 , -0.78032383],
#        [-0.1055002 ,  1.47603423],
#        [ 0.43707226,  0.62227713],
#        [ 0.88921599, -1.20720238],
#        [-1.00978765, -0.81081516],
#        [ 0.25621478,  0.25638123],
#        [ 0.79878724, -0.32295395],
#        [ 1.97436092, -0.84130648],
#        [ 0.79878724,  0.13441593],
#        [-0.19592895,  0.65276845],
#        [-0.82893016, -0.32295395],
#        [ 0.25621478, -0.3839366 ],
#        [ 1.97436092,  2.23831736],
#        [ 1.79350343, -1.32916768],
#        [ 1.34135971, -0.96327178],
#        [ 0.88921599,  1.32357761],
#        [ 1.43178845,  2.23831736],
#        [-0.19592895, -1.29867636],
#        [ 1.88393217,  0.95768171],
#        [ 0.7083585 , -0.74983251],
#        [-1.28107388,  0.37834653],
#        [ 0.79878724, -1.42064166],
#        [ 0.43707226, -0.140006  ],
#        [-0.82893016,  0.43932918],
#        [ 0.07535729, -0.32295395],
#        [-1.00978765,  0.43932918],
#        [-0.73850141, -1.26818503],
#        [-0.01507146,  0.04294195],
#        [-1.37150262, -0.44491925],
#        [ 0.97964473, -1.05474576],
#        [ 1.07007347, -1.26818503],
#        [ 0.07535729, -0.140006  ],
#        [-0.9193589 , -1.60358961],
#        [ 0.79878724, -1.26818503],
#        [ 0.97964473,  2.17733471],
#        [-1.00978765, -1.60358961],
#        [-0.19592895,  0.8357164 ],
#        [ 0.16578603, -0.32295395],
#        [-1.19064513, -1.29867636],
#        [-0.46721518, -1.57309829],
#        [ 0.79878724,  0.56129448],
#        [-0.19592895, -0.35344528],
#        [ 1.70307469, -0.29246263],
#        [ 0.88921599, -1.08523708],
#        [ 0.25621478,  0.07343327],
#        [-0.46721518,  0.92719038],
#        [-1.64278886, -1.48162431],
#        [-1.10021639,  0.62227713],
#        [-0.19592895,  0.56129448],
#        [-0.82893016, -1.14621973],
#        [ 1.16050222, -1.51211563],
#        [ 0.25621478, -0.32295395],
#        [ 1.16050222, -0.78032383],
#        [-0.19592895,  0.07343327],
#        [ 0.25621478,  2.20782604],
#        [ 0.79878724, -1.14621973],
#        [ 0.16578603,  0.04294195],
#        [-1.55236011,  0.13441593],
#        [-0.73850141,  0.16490725],
#        [-0.55764392,  0.19539858],
#        [ 0.88921599, -1.35965901],
#        [ 0.25621478, -0.2619713 ],
#        [-0.28635769,  1.29308628],
#        [ 0.07535729,  0.31736388],
#        [ 0.43707226,  0.16490725],
#        [ 0.88921599, -0.68884985],
#        [ 0.16578603,  0.16490725],
#        [-1.64278886, -1.35965901],
#        [-0.01507146,  0.31736388],
#        [-0.1055002 , -0.29246263],
#        [ 0.34664352, -0.53639323],
#        [-0.1055002 ,  1.68947351],
#        [ 0.97964473, -1.23769371],
#        [-0.1055002 ,  1.71996483],
#        [ 1.25093096,  1.96389544],
#        [-0.9193589 , -0.3839366 ],
#        [ 0.07535729,  0.04294195],
#        [ 0.16578603, -0.2619713 ],
#        [-1.37150262, -1.29867636],
#        [-0.37678643, -0.29246263],
#        [ 0.97964473,  0.13441593],
#        [ 1.88393217, -1.42064166],
#        [ 1.43178845,  0.07343327],
#        [-0.46721518,  1.44554291],
#        [ 1.5222172 ,  0.01245062],
#        [-0.64807267,  0.31736388],
#        [ 1.88393217,  0.77473375],
#        [-1.00978765, -0.53639323],
#        [ 0.7083585 ,  0.28687255],
#        [-1.19064513, -0.44491925],
#        [ 0.25621478,  0.16490725],
#        [-0.37678643, -1.26818503],
#        [ 0.61792975,  2.11635206],
#        [-1.37150262, -1.57309829],
#        [-0.37678643, -0.56688455],
#        [ 0.52750101,  1.93340411],
#        [-1.19064513, -1.14621973],
#        [ 0.79878724, -1.45113298],
#        [-0.19592895, -0.44491925],
#        [ 1.5222172 ,  1.04915568],
#        [ 0.97964473,  1.50652556],
#        [-0.19592895, -0.5059019 ],
#        [-0.01507146,  2.26880869],
#        [-1.28107388, -0.10951468],
#        [-0.01507146,  2.05536941],
#        [-0.55764392, -0.35344528],
#        [-0.37678643, -0.87179781],
#        [ 0.7083585 , -1.45113298],
#        [-0.64807267, -1.66457226],
#        [-1.64278886, -1.54260696],
#        [ 1.07007347,  0.13441593],
#        [ 0.16578603,  1.59799953],
#        [-0.19592895,  0.1039246 ],
#        [ 0.16578603,  0.04294195],
#        [-1.19064513, -1.42064166],
#        [ 0.34664352,  0.07343327],
#        [-0.73850141,  0.40883785],
#        [ 1.5222172 , -1.32916768],
#        [-0.19592895, -0.78032383],
#        [-0.01507146,  0.16490725],
#        [-0.73850141, -0.68884985],
#        [-0.55764392, -0.04853203],
#        [ 0.43707226, -0.47541058],
#        [-0.64807267,  1.99438676],
#        [ 1.34135971,  1.35406893],
#        [ 1.16050222, -1.02425443],
#        [ 1.70307469,  1.93340411],
#        [-0.73850141, -0.2619713 ],
#        [-0.64807267,  0.5917858 ],
#        [-1.00978765, -1.63408094],
#        [-0.37678643, -1.17671106],
#        [ 0.34664352,  0.07343327],
#        [-0.1055002 , -1.11572841],
#        [ 1.61264594,  1.68947351],
#        [ 0.97964473,  1.87242146],
#        [ 0.34664352,  0.04294195],
#        [-0.64807267, -0.23147998],
#        [-0.01507146,  0.07343327],
#        [ 0.34664352, -0.20098865],
#        [ 1.88393217, -0.68884985],
#        [-0.64807267,  1.41505158],
#        [-1.55236011, -0.6278672 ],
#        [-0.01507146,  0.13441593],
#        [ 0.34664352, -0.32295395],
#        [ 1.07007347,  0.5917858 ],
#        [-0.82893016,  0.28687255],
#        [ 1.43178845,  0.37834653],
#        [ 0.25621478, -0.3839366 ],
#        [ 2.06478966, -1.08523708],
#        [-0.19592895,  1.17112098],
#        [-1.46193137,  0.07343327],
#        [ 0.07535729,  0.04294195],
#        [ 0.16578603,  1.11013833],
#        [-0.01507146, -0.3839366 ],
#        [-1.00978765,  0.07343327],
#        [-0.19592895, -1.42064166],
#        [ 1.5222172 ,  1.17112098],
#        [-0.64807267, -1.60358961],
#        [ 0.16578603,  1.96389544],
#        [-0.73850141, -0.81081516],
#        [-0.37678643, -0.81081516],
#        [-0.19592895, -0.96327178],
#        [ 0.34664352, -0.74983251],
#        [ 0.34664352,  0.07343327],
#        [ 0.16578603,  1.96389544],
#        [-0.9193589 ,  2.05536941],
#        [-1.46193137, -1.63408094],
#        [-1.00978765, -1.14621973],
#        [-0.55764392, -0.10951468],
#        [ 0.16578603,  0.1039246 ],
#        [ 0.34664352,  0.28687255],
#        [ 0.88921599, -0.59737588],
#        [ 0.34664352, -1.20720238],
#        [-0.01507146,  0.7137511 ],
#        [ 2.06478966, -0.71934118],
#        [-1.10021639, -1.45113298],
#        [-0.82893016, -0.99376311],
#        [ 0.07535729, -0.44491925],
#        [-0.1055002 , -0.47541058],
#        [-1.55236011, -1.02425443],
#        [ 1.70307469,  1.04915568],
#        [ 0.25621478, -0.3839366 ],
#        [ 0.43707226,  1.17112098],
#        [-1.55236011, -1.42064166],
#        [ 0.25621478, -0.140006  ],
#        [ 0.88921599, -1.51211563],
#        [-1.7332176 ,  0.50031183],
#        [-0.19592895,  0.28687255],
#        [ 1.79350343, -1.11572841],
#        [-0.28635769,  0.07343327],
#        [ 1.07007347, -0.93278046],
#        [-0.9193589 , -1.17671106],
#        [-1.64278886,  0.01245062],
#        [ 0.16578603,  0.28687255],
#        [-1.00978765,  0.3478552 ],
#        [-1.10021639,  0.31736388],
#        [-0.82893016,  0.4698205 ],
#        [ 1.61264594, -0.93278046],
#        [ 1.16050222,  0.56129448],
#        [ 1.07007347,  0.56129448],
#        [ 1.34135971,  2.45175664],
#        [-0.19592895, -0.140006  ],
#        [ 0.43707226, -0.47541058],
#        [-0.28635769, -0.81081516],
#        [-0.01507146, -0.53639323],
#        [ 0.97964473, -1.20720238],
#        [-0.73850141, -0.81081516],
#        [-0.1055002 , -0.53639323],
#        [-0.9193589 , -0.47541058],
#        [-1.00978765,  1.47603423]])

# %%
X_test
# Out:
#      Age  EstimatedSalary
# 132   30            87000
# 309   38            50000
# 341   35            75000
# 196   30            79000
# 246   35            50000
# ..   ...              ...
# 216   49            65000
# 259   45           131000
# 49    31            89000
# 238   46            82000
# 343   47            51000
#
# [120 rows x 2 columns]

# %%
X_test_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 X_test_scaled
#
# NameError: name 'X_test_scaled' is not defined

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)

X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# # Effect of Scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'], color = 'red')
ax2.set_title('After Scaling')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)
ax1.set_title('Before Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
ax2.set_title('After Scaling')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)
ax1.set_title('Before Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
ax2.set_title('After Scaling')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

sns.kdeplot(X_train['Age'], ax=ax1)
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
ax2.set_title('Age  Distribution  after Standard Scaling')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
ax2.set_title('Salary  Distribution  after Standard Scaling')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # why Scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train, y_train)
lr_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
 
scaler = StandardScaler()

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the test data
X_test_scaled = scaler.transform(X_test)

# Convert the scaled data back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

print(X_train_scaled)
print(X_test_scaled)
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
from sklearn.metrics  import accuracy_score

# %%
print('Actual', accuracy_score(y_test,y_pred))
print('Scaled', accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.6583333333333333
# Scaled 0.8666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train )
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_Scaled)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print('Actual', accuracy_score(y_test,y_pred))
print('Scaled', accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.875
# Scaled 0.8666666666666667

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000
